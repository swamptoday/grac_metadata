# %%
import pandas as pd

# %%
grac_old = pd.read_excel('GRAC_Metadata_Authors.xlsx')
grac_new = pd.read_excel('updated_data.xlsx')

# %%
total_counts = grac_new.shape[0]

missing_data = pd.DataFrame({
    'Missing': grac_new.isnull().sum() * 100 / total_counts ,
    'Not Missing': grac_new.notnull().sum() * 100 / total_counts
})

# %%
missing_data
# Out:
#                                        Missing  Not Missing
# Автор                                 0.010854    99.989146
# Рік еміграції                        99.071989     0.928011
# Регіон2                              94.977342     5.022658
# Регіон3                              99.023146     0.976854
# Регіон4                              99.823624     0.176376
# Регіон5                              99.970152     0.029848
# Примітки                            100.000000     0.000000
# Повне ім'я                           92.765854     7.234146
# Рік смерті                           95.970477     4.029523
# URL                                  92.763140     7.236860
# Місце народження                     97.590427     2.409573
# Регіон                               96.439910     3.560090
# Рік народження                       85.629392    14.370608
# Місце народження (населений пункт)   91.799853     8.200147
# Район                                92.665455     7.334545
# ...
